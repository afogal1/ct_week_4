# %%
import ROI
# Out:
# Welcome to the Real Estate Cash on Cash ROI Calculator!
#
#             Please select a number option and enter information for the following sections:
#             1) Property
#             2) Income
#             3) Expenses
#             4) Investment
#             When section 1) ~ 4) is completed,
#             Enter 5) to compute ROI or 'q' to quit.
#             1
# Please enter the property type (e.g. Condo): Condo
# Please enter the property price: $100,000
#
#             Please select a number option and enter information for the following sections:
#             1) Property
#             2) Income
#             3) Expenses
#             4) Investment
#             When section 1) ~ 4) is completed,
#             Enter 5) to compute ROI or 'q' to quit.
#             2
# ...
# Total Monthly Income: $0
# 1) Rental Income: $0
# 2) Laundry: $0
# 3) Storage: $0
# 4) Miscellaneous: $0
#
#                 --- Please select the appropriate number options and enter the data
# ...
